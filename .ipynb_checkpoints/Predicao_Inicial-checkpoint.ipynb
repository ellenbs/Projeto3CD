# %% [markdown]
# # Predição Inicial

# %% [markdown]
# #### Alunos: Ellen Shen, Enzo Neto, Gabriel Huerta, Giulia Castro

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from scipy.stats import norm
from mpl_toolkits.mplot3d import Axes3D

from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

np.random.seed(42)

# %%
top_2017 = pd.read_csv("top_2017.csv", index_col=1)
top_2018 = pd.read_csv('top_2018.csv', index_col=1)

# %%
top_2017.head(3)
# Out:
#                                                        id     artists  \
# name
# Shape of You                        7qiZfU4dY1lWllzX7mPBI  Ed Sheeran
# Despacito - Remix                   5CtI0qwDJkDQGwXD1H1cL  Luis Fonsi
# Despacito (Featuring Daddy Yankee)  4aWmUDTfIPGksMNLV2rQP  Luis Fonsi
#
#                                     danceability  energy  key  loudness  mode  \
# name
# Shape of You                               0.825   0.652  1.0    -3.183   0.0
# Despacito - Remix                          0.694   0.815  2.0    -4.328   1.0
# Despacito (Featuring Daddy Yankee)         0.660   0.786  2.0    -4.757   1.0
#
#                                     speechiness  acousticness  \
# name
# Shape of You                             0.0802         0.581
# Despacito - Remix                        0.1200         0.229
# Despacito (Featuring Daddy Yankee)       0.1700         0.209
#
#                                     instrumentalness  liveness  valence  \
# name
# Shape of You                                     0.0    0.0931    0.931
# Despacito - Remix                                0.0    0.0924    0.813
# Despacito (Featuring Daddy Yankee)               0.0    0.1120    0.846
#
#                                       tempo  duration_ms  time_signature
# name
# Shape of You                         95.977     233713.0             4.0
# Despacito - Remix                    88.931     228827.0             4.0
# Despacito (Featuring Daddy Yankee)  177.833     228200.0             4.0

# %%
top_2018.head(3)
# Out:
#                                                id       artists  danceability  \
# name
# God's Plan                  6DCZcSspjsKoFjzjrWoCd         Drake         0.754
# SAD!                        3ee8Jmje8o58CHK66QrVC  XXXTENTACION         0.740
# rockstar (feat. 21 Savage)  0e7ipj03S05BNilyu5bRz   Post Malone         0.587
#
#                             energy  key  loudness  mode  speechiness  \
# name
# God's Plan                   0.449  7.0    -9.211   1.0       0.1090
# SAD!                         0.613  8.0    -4.880   1.0       0.1450
# rockstar (feat. 21 Savage)   0.535  5.0    -6.090   0.0       0.0898
#
#                             acousticness  instrumentalness  liveness  valence  \
# name
# God's Plan                        0.0332          0.000083     0.552    0.357
# SAD!                              0.2580          0.003720     0.123    0.473
# rockstar (feat. 21 Savage)        0.1170          0.000066     0.131    0.140
#
#                               tempo  duration_ms  time_signature
# name
# God's Plan                   77.169     198973.0             4.0
# SAD!                         75.023     166606.0             4.0
# rockstar (feat. 21 Savage)  159.847     218147.0             4.0

# %%
plt3d = plt.figure().gca(projection="3d")
plt3d.scatter(top_2017.danceability, top_2017.energy, top_2017.loudness)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dados_entrada = top_2017.loc[:,("danceability", "energy", "acousticness")]

# %%
three_means = cluster.MiniBatchKMeans(n_clusters=3)

# %%
three_means.fit(dados_entrada)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10, n_clusters=3,
#         n_init=3, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
saida = three_means.predict(dados_entrada)

# %%
saida
# Out:
# array([1, 2, 2, 2, 2, 0, 0, 2, 0, 0, 2, 2, 0, 0, 0, 2, 2, 2, 1, 2, 2, 2,
#        1, 1, 2, 1, 2, 0, 1, 0, 1, 0, 2, 1, 2, 1, 0, 0, 0, 2, 0, 2, 0, 2,
#        2, 1, 1, 0, 0, 0, 2, 0, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 0, 2, 0, 1,
#        2, 0, 2, 0, 2, 0, 0, 2, 2, 2, 1, 2, 0, 2, 1, 1, 0, 2, 2, 1, 0, 2,
#        2, 2, 1, 0, 2, 2, 0, 2, 2, 1, 0, 2])

# %%
conjunto = dados_entrada.copy()

# %%
conjunto["saida"] = saida

# %%
conjunto.head()
# Out:
#                                     danceability  energy  acousticness  saida
# name
# Shape of You                               0.825   0.652        0.5810      1
# Despacito - Remix                          0.694   0.815        0.2290      2
# Despacito (Featuring Daddy Yankee)         0.660   0.786        0.2090      2
# Something Just Like This                   0.617   0.635        0.0498      2
# I'm the One                                0.609   0.668        0.0552      2

# %%
plt3d = plt.figure().gca(projection="3d")
grupo0 = conjunto[conjunto.saida==0]
grupo1 = conjunto[conjunto.saida==1]
grupo2 = conjunto[conjunto.saida==2]

plt3d.scatter(grupo0.danceability, grupo0.energy, grupo0.acousticness, color="r")
plt3d.scatter(grupo1.danceability, grupo1.energy, grupo1.acousticness, color="g")
plt3d.scatter(grupo2.danceability, grupo2.energy, grupo2.acousticness, color="b")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.rcParams["figure.figsize"] = [5,3]
plt.rcParams["axes.titlesize"] = 10
plt.rcParams["xtick.labelsize"] = 8
plt.rcParams["ytick.labelsize"] = 8
plt.rcParams["axes.labelsize"] = 8
plt.rcParams["lines.markersize"] = 10
top_2017.danceability.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
top_2018.danceability.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
top_2017.energy.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
top_2018.energy.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
top_2017.acousticness.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
top_2018.acousticness.plot.hist(density=True, bins=20)
# Out:
# <img src="data:image/png;base64,..." width="500">
