# %% [markdown]
# # Projeto 3 - Naive Bayes

# %% [markdown]
# **Alunos:** Ellen Shen, Enzo Neto, Gabriel Huerta, Giulia Castro.

# %% [markdown]
# Turma B

# %% [markdown]
# ___

# %% [markdown]
# -introdução-

# %% [markdown]
# -pergunta-

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.naive_bayes import MultinomialNB

# %%
playlist = pd.read_excel("base_naive_bayes.xlsx", index_col=0)

# %%
y_teste = playlist.copy()
y_teste.drop(columns=["saida"])
# Out:
#                                                     danceability  energy  \
# name
# Too Good At Goodbyes                                       0.698   0.375
# Nevermind                                                  0.592   0.691
# Thunder                                                    0.600   0.810
# Starving                                                   0.721   0.626
# Despacito (Featuring Daddy Yankee)                         0.660   0.786
# 1-800-273-8255                                             0.629   0.572
# Downtown                                                   0.775   0.679
# Congratulations                                            0.630   0.804
# God is a woman                                             0.602   0.658
# Me RehÃºso                                                 0.744   0.804
# Unforgettable                                              0.726   0.769
# Galway Girl                                                0.624   0.876
# In My Feelings                                             0.835   0.626
# EscÃ¡pate Conmigo                                          0.747   0.864
# El Amante                                                  0.683   0.691
# Let Me Go (with Alesso, Florida Georgia Line & ...         0.663   0.708
# HUMBLE.                                                    0.908   0.621
# lovely (with Khalid)                                       0.351   0.296
# FRIENDS                                                    0.626   0.880
# I'm the One                                                0.609   0.668
# Wild Thoughts                                              0.671   0.672
# Me Niego                                                   0.777   0.779
# Young Dumb & Broke                                         0.798   0.539
# Your Song                                                  0.855   0.624
# Yes Indeed                                                 0.964   0.346
# Taste (feat. Offset)                                       0.884   0.559
# Nonstop                                                    0.912   0.412
# FEFE (feat. Nicki Minaj & Murda Beatz)                     0.931   0.387
# Everybody Dies In Their Nightmares                         0.734   0.570
# The Middle                                                 0.753   0.657
# ...                                                          ...     ...
# I Donâ€™t Wanna Live Forever (Fifty Shades Dark...         0.735   0.451
# How Far I'll Go - From "Moana"                             0.314   0.555
# Just Hold On                                               0.647   0.932
# Malibu                                                     0.573   0.781
# More Than You Know                                         0.644   0.743
# Vaina Loca                                                 0.754   0.805
# Cold (feat. Future)                                        0.697   0.716
# Fake Love                                                  0.927   0.488
# Him & I (with Halsey)                                      0.589   0.731
# Otra Vez (feat. J Balvin)                                  0.832   0.772
# Believer                                                   0.779   0.787
# Freaky Friday (feat. Chris Brown)                          0.755   0.599
# I Feel It Coming                                           0.768   0.813
# Bad and Boujee (feat. Lil Uzi Vert)                        0.927   0.665
# Sorry Not Sorry                                            0.704   0.633
# IDGAF                                                      0.836   0.544
# Never Be the Same                                          0.637   0.713
# 2U (feat. Justin Bieber)                                   0.548   0.650
# Back To You - From 13 Reasons Why ? Season 2 So...         0.601   0.724
# You Don't Know Me - Radio Edit                             0.876   0.669
# SAD!                                                       0.740   0.613
# Stay (with Alessia Cara)                                   0.679   0.634
# Sin Pijama                                                 0.791   0.745
# Paris                                                      0.653   0.658
# Young Dumb & Broke                                         0.798   0.539
# ReggaetÃ³n Lento (Bailemos)                                0.761   0.838
# I Like It                                                  0.816   0.726
# Dusk Till Dawn - Radio Edit                                0.258   0.437
# Dura                                                       0.791   0.848
# Redbone                                                    0.743   0.359
#
#                                                     valence
# name
# Too Good At Goodbyes                                 0.5340
# Nevermind                                            0.0796
# Thunder                                              0.2980
# Starving                                             0.5580
# Despacito (Featuring Daddy Yankee)                   0.8460
# 1-800-273-8255                                       0.3860
# Downtown                                             0.6190
# Congratulations                                      0.4920
# God is a woman                                       0.2680
# Me RehÃºso                                           0.4260
# Unforgettable                                        0.7330
# Galway Girl                                          0.7810
# In My Feelings                                       0.3500
# EscÃ¡pate Conmigo                                    0.7540
# El Amante                                            0.7320
# Let Me Go (with Alesso, Florida Georgia Line & ...   0.7420
# HUMBLE.                                              0.4210
# lovely (with Khalid)                                 0.1200
# FRIENDS                                              0.5340
# I'm the One                                          0.8110
# Wild Thoughts                                        0.6320
# Me Niego                                             0.7680
# Young Dumb & Broke                                   0.3940
# Your Song                                            0.9620
# Yes Indeed                                           0.5620
# Taste (feat. Offset)                                 0.3420
# Nonstop                                              0.4220
# FEFE (feat. Nicki Minaj & Murda Beatz)               0.3760
# Everybody Dies In Their Nightmares                   0.6890
# The Middle                                           0.4370
# ...                                                     ...
# I Donâ€™t Wanna Live Forever (Fifty Shades Dark...   0.0862
# How Far I'll Go - From "Moana"                       0.1590
# Just Hold On                                         0.3740
# Malibu                                               0.3430
# More Than You Know                                   0.5440
# Vaina Loca                                           0.5550
# Cold (feat. Future)                                  0.5060
# Fake Love                                            0.6050
# Him & I (with Halsey)                                0.1910
# Otra Vez (feat. J Balvin)                            0.7040
# Believer                                             0.7080
# Freaky Friday (feat. Chris Brown)                    0.7550
# I Feel It Coming                                     0.5790
# Bad and Boujee (feat. Lil Uzi Vert)                  0.1750
# Sorry Not Sorry                                      0.8630
# IDGAF                                                0.5100
# Never Be the Same                                    0.2430
# 2U (feat. Justin Bieber)                             0.5570
# Back To You - From 13 Reasons Why ? Season 2 So...   0.5080
# You Don't Know Me - Radio Edit                       0.6820
# SAD!                                                 0.4730
# Stay (with Alessia Cara)                             0.4980
# Sin Pijama                                           0.8200
# Paris                                                0.2190
# Young Dumb & Broke                                   0.3940
# ReggaetÃ³n Lento (Bailemos)                          0.7100
# I Like It                                            0.6500
# Dusk Till Dawn - Radio Edit                          0.0967
# Dura                                                 0.8280
# Redbone                                              0.5870
#
# [160 rows x 3 columns]

# %%
x_teste = list(playlist.saida)

# %%
teste = MultinomialNB.fit(x_teste,y_teste)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-0afe6a53dc50> in <module>
# ----> 1 teste = MultinomialNB.fit(x_teste,y_teste)
#
# TypeError: fit() missing 1 required positional argument: 'y'
